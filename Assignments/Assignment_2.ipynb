# %% [markdown]
# ## Write a program that takes a number from the user and:
#
#     Prints "Positive" if the number is greater than 0
#
#     Prints "Negative" if the number is less than 0
#
#     Prints "Zero" if the number is 0

# %%
num = int(input("Enter a number: "))

if num > 0:
    print("Number is positive")
elif num < 0:
    print("Number is negative")
elif num == 0:
    print("Number is zero")
# Out:
# Enter a number:  0
# Number is zero

# %% [markdown]
# ## Take an integer input from the user and check:
#
#     If the number is even, print "Even number"
#
#     Otherwise, print "Odd number"

# %%
num = int(input("Enter a number: "))

if num % 2 == 0:
    print("Number is even")
else:
    print("Number is odd")
# Out:
# Enter a number:  5
# Number is odd

# %% [markdown]
# ## Ask the user for their age.
#
#     If age is 18 or above, print "You are eligible to vote"
#
#     Else, print "You are not eligible to vote"

# %%
age = int(input("Enter your age: "))

if age >= 18:
    print("You are eligible to vote")
else:
    print("You are not eligible to vote")
# Out:
# Enter your age:  12
# You are not eligible to vote

# %% [markdown]
# ## Take two numbers as input and:
#
#     Print which number is larger
#
#     If both are equal, print "Both numbers are equal"

# %%
num_1 = int(input("Enter first number: "))
num_2 = int(input("Enter second number: "))

if num_1 > num_2:
    print("First Number is greater")
elif num_2 > num_1:
    print("Second Number is greater")
elif num_1 == num_2:
    print("Both numbers are equal")
# Out:
# Enter first number:  5
# Enter second number:  2
# First Number is greater

# %% [markdown]
# ## Ask the user to enter their marks (0–100).
#
#     If marks are 40 or above, print "Pass"
#
#     Otherwise, print "Fail"

# %%
marks = float(input("Enter your marks: "))

if marks >= 40:
    print("Pass")
else:
    print("Fail")
# Out:
# Enter your marks:  45
# Pass

# %% [markdown]
# ## Take marks as input and print the grade:
#
#     90 or above → "Grade A"
#
#     70 to 89 → "Grade B"
#
#     50 to 69 → "Grade C"
#
#     Below 50 → "Fail"

# %%
marks = float(input("Enter your marks: "))

if marks >= 90:
    print("Grade A")
elif marks >= 70:
    print("Grade B")
elif marks >=50:
    print("Grade C")
else:
    print("Fail")
# Out:
# Enter your marks:  89
# Grade B

# %% [markdown]
# ## Ask the user for a year and check:
#
#     If the year is divisible by 4 → "Leap Year"
#
#     Otherwise → "Not a Leap Year"

# %%
year = int(input("Enter a year and check wheather its leap year or not: "))

if year % 4 == 0:
    print("Leap Year")
else:
    print("Not a Leap Year")
# Out:
# Enter a year and check wheather its leap year or not:  2024
# Leap Year

# %% [markdown]
# ## Ask the user to enter a password:
#
#     If password is "python123" → print "Access Granted"
#
#     Else → print "Access Denied"

# %%
password = "python123"
user_pass = input("Enter a password: ")

if user_pass == password:
    print("Access Granted")
else:
    print("Access Denied")
# Out:
# Enter a password:  python123
# Access Granted

# %% [markdown]
# ### Ask the user for temperature in Celsius:
#
#     Above 35 → "Very Hot"
#
#     25 to 35 → "Hot"
#
#     15 to 24 → "Normal"
#
#     Below 15 → "Cold"

# %%
temp_in_C = float(input("Enter a temperture in Celsius: "))

if temp_in_C >= 35:
    print("Very Hot")
elif temp_in_C >= 25:
    print("Hot")
elif temp_in_C >=15:
    print("Normal")
else:
    print("Cold")
# Out:
# Enter a temperture in Celsius:  27
# Hot

# %% [markdown]
# ## Take marks from the user:
#
#     90–100 → "Excellent"
#
#     75–89 → "Very Good"
#
#     60–74 → "Good"
#
#     40–59 → "Average"
#
#     Below 40 → "Fail"

# %%
marks = float(input("Enter your marks: "))

if 90 <= marks <= 100:
    print("Excellent")
elif 75 <= marks < 90:
    print("Very Good")
elif 60 <= marks < 75:
    print("Good")
elif 40 <= marks < 60:
    print("Average")
else:
    print("Fail")
# Out:
# Enter your marks:  78
# Very Good

# %% [markdown]
# ## Ask the user for:
#
#     Two numbers
#
#     An operator (+, -, *, /)
#
#     if operator + perform addition
#     if operator - perform subtraction
#     if operator * perform multiplication
#     if operator / perform division

# %%
num_1 = int(input("Enter first number: "))
num_2 = int(input("Enter second number: "))

operator = input("Enter an Operator: ")

if operator == "+":
    print(num_1 + num_2)
elif operator == "-":
    print(num_1 - num_2)
elif operator == "*":
    print(num_1 * num_2)     
elif operator == "/":
    if num_2 == 0:
        print("0 is not divisible")
    else:
        print(num / num2)
else:
    print("Enter a correct operator")
# Out:
# Enter first number:  3
# Enter second number:  9
# Enter an Operator:  *
# 27

# %% [markdown]
# ## Take age as input:
#
#     Age < 13 → "Child"
#
#     13–19 → "Teenager"
#
#     20–59 → "Adult"
#
#     60 or above → "Senior Citizen"

# %%
age = int(input("Enter your age: "))

if age < 13:
    print("Child")
elif 13 <= age <= 19:
    print("Teenager")
elif 20 <= age <= 59:
    print("Adult")
else:
    print("Senior Citizens")
# Out:
# Enter your age:  56
# Adult

# %% [markdown]
# ## Login System
#
# #### Ask for:Username Password
#
#     Conditions:
#
#     If username is "admin" and password is "1234" → "Login Successful"
#
#     Else → "Invalid Credentials"

# %%
username = "admin"
password = "1234"

user_username = input("Enter a username: ")
user_pass = input("Enter a password: ")

if user_username == username and user_pass == password:
   print("Login Successful")       
else:
    print("Invalid Credentials")
# Out:
# Enter a username:  admin
# Enter a password:  1234
# Login Successful

# %% [markdown]
# ## Ask the user for a number:
#
#     If divisible by 3 and 5 → "FizzBuzz"
#
#     If divisible by only 3 → "Fizz"
#
#     If divisible by only 5 → "Buzz"
#
#     Else → "Not divisible by 3 or 5"

# %%
num = int(input("Enter a number: "))

if num % 3 == 0 and num % 5 == 0:
    print("FizzBuzz")
elif num % 3 == 0:
    print("Fizz")
elif num % 5 == 0:
    print("Buzz")
else:
    print("Not divisible by 3 or 5")
# Out:
# Enter a number:  19
# Not divisible by 3 or 5

# %% [markdown]
# ## Ask the user for:
#
#     Account balance
#
#     Withdrawal amount
#
# ## Conditions:
#
#     If balance is sufficient:
#
#     If withdrawal amount is multiple of 500 → "Transaction Successful"
#
#     Else → "Amount must be multiple of 500"
#
#     Else → "Insufficient Balance"

# %%
account_balance = 10000
withdrawal_amount = int(input("Enter a with drawal amount: "))

if account_balance > withdrawal_amount:
    if  withdrawal_amount % 500 == 0:
         print("Transaction Successsful")
    else:
        print("Amount must be multiple of 500 ")
else:
    print("Insufficient Balance")
# Out:
# Enter a with drawal amount:  1000
# Transaction Successsful

# %% [markdown]
# ## Ask the user:
#
#     Attendance percentage
#
#     Exam fee paid (yes or no)
#
# ## Conditions:
#
#     If attendance ≥ 75:
#
#     If fee is paid → "Eligible for Exam"
#
#     Else → "Pay exam fee first"
#
#     Else → "Not eligible due to low attendance"

# %%
attendance_percentage = float(input("Enter attendance percentage: "))

if attendance_percentage >= 75:
    fee_paid = input("Is exam fee paid? (write 'yes' or 'no'): ").lower()
    if fee_paid == "yes":
        print("Eligible for Exam")
    else:
        print("Pay exam fee first")
else:
    print("Not eligible due to low attendance")
# Out:
# Enter attendance percentage:  89
# Is exam fee paid? (write 'yes' or 'no'):  no
# Pay exam fee first

# %% [markdown]
# ## Online Order System
#
#     Ask:
#
#     Order amount
#
#     User type (regular / premium)
#
# ### Conditions:
#
#     If order ≥ 1000:
#
#     Premium → 20% discount
#
#     Regular → 10% discount
#
#     Else → "No discount available"

# %%
order_amount = float(input("Enter a order amount: "))

if order_amount >= 1000:
    user_type = input("Enter a type of a user (regular / premium)?: ").lower()
    if user_type == "premium":
        print("20% discount on your order")
    else:
        print("10% discount on your order")
else:
    print("No discount available")
# Out:
# Enter a order amount:  950
# No discount available

# %% [markdown]
# ## Ask the user:
#
#     Age
#
#     Driving license (yes / no)
#
# ## Conditions:
#
#     If age ≥ 18:
#
#     If license = yes → "You can drive"
#
#     Else → "Get a driving license"
#
#     Else → "You are underage"

# %%
age = int(input("Enter your age: "))

if age >= 18:
    license = input("Do you have a Driving License? (yes or no): ").lower()
    if license == "yes":
        print("You can drive")
    else: 
        print("Get a driving license")
else:
    print("You are underage")
# Out:
# Enter your age:  19
# Do you have a Driving License? (yes or no):  yes
# You can drive

# %% [markdown]
# ## Ask the user:
#
#     Internet status (on / off)
#
#     Data balance (in MB)
#
# ### Conditions:
#
#     If internet is on:
#
#     If data balance > 0 → "You are connected to the internet"
#
#     Else → "No data balance"

# %%
internet_status = input("Enter a internet status? (on or off): ").lower()

if internet_status == "on":
    data_balance = int(input("Enter a data balance in MB: "))
    if data_balance > 0:
        print("You are connected to the internet")
    else:
        print("No data balance")
else:
    print("Your internet status is off")
# Out:
# Enter a internet status? (on or off):  ON
# Enter a data balance in MB:  23
# You are connected to the internet

# %% [markdown]
# ## Ask the user for a password:
#
#     If password length ≥ 8:
#
#     If it contains "@" → "Strong password"
#
#     Else → "Add a special character"
#
#     Else → "Password too short"

# %%
password = str(input("Enter a password: "))

if len(password) >= 8:
    if "@" in password:
        print("Strong password")
    else:
        print("Add a special character")
else:
    print("Password too short")
# Out:
# Enter a password:  taha@1234
# Strong password

# %% [markdown]
# ## Movie Ticket Eligibility
#
#     Ask the user:
#
#     Age
#
#     Parental permission (yes / no)
#
# ## Conditions:
#
#     If age ≥ 18:
#
#         "Ticket Allowed"
#
#     Else:
#
#     If permission is yes → "Ticket Allowed with Permission"
#
#     Else → "Ticket Not Allowed"

# %%
age = int(input("Enter your age: "))

if age >= 18:
    permission = input("Do you allow Parental permission ? (yes or no): ").lower()
    if permission == "yes":
        print("Ticket Allowed")
    else: 
        print("Ticket Allowed with Permission")
else:
    print("Ticket Not Allowed")
# Out:
# Enter your age:  19
# Do you allow Parental permission ? (yes or no):  no
# Ticket Allowed with Permission

# %% [markdown]
# ## Online Exam Access
#
#     Ask the user:
#
#     Login status (yes / no)
#
#     Webcam status (on / off)
#
# ## Conditions:
#
#     If logged in:
#
#     If webcam is on → "Exam Started"
#
#     Else → "Turn on webcam"
#
#     Else → "Please login first"

# %%
login_status = input("Are you login? (yes or no): ").lower()

if login_status == "yes":
    webcam_status = input("Are you login? (on or off): ").lower()
    if webcam_status == "on":
        print("Exam Started")
    else:
        print("Turn on webcam")
else:
    print("Please login first")
# Out:
# Are you login? (yes or no):  yes
# Are you login? (on or off):  on
# Exam Started

# %% [markdown]
# ## Bank Loan Approval
# Ask the user:
#
#     Monthly income
#
#     Credit score
#
# ### Conditions:
#
#     If income ≥ 50,000:
#
#     If credit score ≥ 700 → "Loan Approved"
#
#     Else → "Low credit score"
#
#     Else → "Income too low"

# %%
monthly_income = float(input("Enter your monthly income: "))

if(monthly_income >= 50000):
    credit_score = int(input("Enter your credit score: "))
    if credit_score >= 700:
        print("Loan Approved")
    else:
        print("Low credit score")
else:
    print("Income too low")
# Out:
# Enter your monthly income:  78000
# Enter your credit score:  890
# Loan Approved

# %% [markdown]
# ## App Subscription Access
#
#     Ask the user:
#
#     Subscription type (free / premium)
#
#     Feature name (download / stream)
#
# ## Conditions:
#
#     If subscription is premium:
#
#     "Access Granted"
#
#     Else:
#
#     If feature is stream → "Access Granted"
#
#     Else → "Upgrade to Premium"

# %%
subscription = input("Type of Subscription (free / premium) ? : ").lower()

if subscription == "premium":
    feature = input("(download / stream)? :").lower()
    if feature == "stream" or "download":
        print("Access granted")
else:
    print("Upgrade to Premium")
# Out:
# Type of Subscription (free / premium) ? :  premium
# (download / stream)? : download
# Access granted

# %% [markdown]
# ## Device Charging Status
#
#     Ask the user:
#
#     Charger connected (yes / no)
#
#     Battery percentage
#
# ## Conditions:
#
#     If charger connected:
#
#     If battery < 100 → "Charging"
#
#     Else → "Battery Full"
#
#     Else → "Connect charger"

# %%
is_connected = input("Is charger connected? (yes or no): ").lower()

if is_connected == "yes":
    battery_percent = int(input("Enter a battery percentage: "))
    if battery_percent < 100:
        print("Charging..")
    else:
        print("Battery Full")
else:
    print("Connect Charger")
# Out:
# Is charger connected? (yes or no):  yes
# Enter a battery percentage:  100
# Battery Full
